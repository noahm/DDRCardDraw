# %%
import requests

data_src = {}
for src in ["titletbl", "actbl", "datatbl"]:
    x = requests.get(f"https://textage.cc/score/{src}.js")
    if x.status_code < 400:
        x.encoding = x.apparent_encoding
        data_src[src] = x.text
    else:
        data_src[src]

# %%
import json
import re

data = []
diffLookup = {
    "N": "normal",
    "H": "hyper",
    "A": "another"
}
with open(r"C:\Users\telpi\Documents\GitHub\DDRCardDraw\iidx-motl5-base.txt", 'r', encoding='utf-8') as fp:
    for line in fp:
        tokens = line.split('\t')
        if len(tokens) <= 1:
            break

        lvl = int(re.sub('\D', '', tokens[0]))
        name = tokens[1]
        diffClass = diffLookup[tokens[2]]
        artist = f"P1 {tokens[3]} | P2 {tokens[4]}"

        data.append({
            "name": name,
            "artist": artist,
            "bpm": "0",
            "jacket": "",
            "charts": [{
                "lvl": lvl,
                "style": "single",
                "diffClass": diffClass
            }]
        })

with open(r"C:\Users\telpi\Documents\GitHub\DDRCardDraw\iidx-motl5-base.json", 'w', encoding='utf-8') as fp:
    json.dump(data, fp)

# %%
                SBo SB  SN  SH  SA  SX  DB  DN  DH  DA  DX
# [ttnum SB ... DX chartrev]
# ttnum:
#   & 0b0001    is in AC
#   & 0b0010    is in CS
#   & 0b0100    has beginner
#   & 0b1000    has leggendaria
              0,0,0,1,1,2,3,8,3,9,3,0,0,0,0,1,3,8,3,0,0,0,0,"(CS9th)"
'aegis'		:[3,0,0,0,0,6,F,8,F,B,F,0,0,0,0,5,F,8,F,A,F,0,0],
'absolute'	:[B,3,1,3,1,6,7,8,7,A,7,B,F,0,0,6,7,8,7,B,7,B,F,""],
'abso_k'	:[1,0,0,0,0,5,F,8,F,B,F,0,0,0,0,5,F,8,F,B,F,0,0],
'absoevil'	:[1,0,0,0,0,6,F,A,F,C,F,0,0,0,0,6,F,A,F,C,F,0,0,""],

# [version, id, opt, genre, artist, title, subtitle]
'begincr5':[0,3912,1,"TECHNO","QUADRA / Remixed by QUADRA","Beginning of life","(THE GROUND PULSE MIX)"],



'2player'	:[   0,   0, 511, 840,1302,   0,   0, 526, 843,1368,   0,"129`220"],

# %%
s
# Out:
# 'VERINDEX=0;\nIDINDEX=1;\nOPTINDEX=2;\nGENREINDEX=3;\nARTISTINDEX=4;\nTITLEINDEX=5;\nSUBTITLEINDEX=6;\nSS=35;\n\ntitletbl={\n\'321star5\':[0,3901,1,"TECHNO POP","DJ SIMON","321 STARS"],\n\'321stars\':[0,3902,1,"TECHNO POP","DJ SIMON","321 STARS"],\n\'5eternal\':[0,3903,1,"RAGGA JUNGLE","GUHROOVY fw. NO+CHIN","5PM ETERNAL"],\n\'80s_caps\':[0,3904,1,"DISCOTHEQUE","め組upper-slope","80\'s CAPSULE"],\n\'acidvis\':[0,3905,1,"LIQUID FUNK","L.E.D.","ACID VISION"],\n\'a_galaxy\':[24,3906,1,"UPLIFTING TRANCE","NISH","Around The Galaxy"],\n\'atkmusc5\':[0,3907,1,"HARD TECHNO","DJ FX","Attack the music"],\n\'atkmusic\':[0,3908,1,"HARD TECHNO","DJ FX","Attack the music"],\n\'backfwfv\':[0,3909,1,"TRANCE","Sota Fujimori","Back Into The Light","<br>-Feeling Won\'t Fade Vocal Mix-"],\n\'btltrain\':[23,3910,1,"HARD DANCE","Sota Fujimori","Battle Train","-IIDX Edition-"],\n\'begin_cr\':[0,3911,1,"TECHNO","QUADRA / Remixed by QUADRA","Beginning of life","(THE GROUND PULSE MIX)"],\n\'begincr5\':[0,3912,1,"TECHNO","QUADRA / Remixed by QUADRA","Beginning of life","(THE GROUND PULSE MIX)"],\n\'beyond\':[22,3913,1,"WORLD/ELECTRONICA","猫叉Master","Beyond The Earth"],\n\'biometri\':[0,3914,1,"RAGGACORE","GUHROOVY fw. NO+CHIN","Biometrics Warrior"],\n\'bleedluv\':[0,3915,1,"PROVIDENCE R","Xephia (Tatsh+Yuta)","Bleeding Luv","〜Immorality act〜"],\n\'b_mirage\':[22,3916,1,"NU STYLE GABBA","DJ CHUCKY","BLUE MIRAGE"],\n\'brainstm\':[21,3917,1,"TRANCECORE MEETS GABBA","Hardcore United Tokyo(teranoid & DJ TECHNORCH)","BRAINSTORM"],\n\'breathls\':[0,3918,1,"DIST.LOUNGE","Studio Bongo Mango feat.Tomoko Kataoka","breathless"],\n\'cracker\':[0,3919,1,"HIPHOP","GWASHI","c-r-a-c-k-ER"],\n\'caldera5\':[0,3920,1,"HARDCORE BREAKBEATS","CALF","CALDERA"],\n\'caldera\':[0,3921,1,"HARDCORE BREAKBEATS","CALF","CALDERA"],\n\'clbrtion\':[0,3922,1,"SOUL MIX","WaveGroup/DJ TK-ST","Celebration"],\n\'chain_of\':[22,3923,1,"FULL ON","kors k VS 猫叉Master+","Chain of pain"],\n\'change_r\':[0,3924,1,"BALLAD","RYOTA MITSUNAGA","Changes"],\n\'claiomh\':[21,3925,1,"ILUZIO","DJ Yoshitaka VS S.S.D.","Claiomh Solais"],\n\'cookie_b\':[20,3926,1,"BREAK CORE","L.E.D. vs TOMOSUKE fw.crimm","Cookie Bouquets"],\n\'crymson\':[0,3927,1,"DIGITAL HARDCORE","RAM","CRYMSON"],\n\'crymson5\':[0,3928,1,"DIGITAL HARDCORE","RAM","CRYMSON"],\n\'dengue\':[0,3929,1,"ORIENTAL AMBIENT","Macky","DENGUE"],\n\'denim\':[28,3930,1,"TECHNO","SLAKE","DENIM"],\n\'denim5\':[0,3931,1,"TECHNO","SLAKE","DENIM"],\n\'drkmnky5\':[0,3932,1,"MINIMAL","DJ ODDBALL","DRUNK MONKY"],\n\'drkmonky\':[26,3933,1,"MINIMAL","DJ ODDBALL","DRUNK MONKY"],\n\'dune\':[0,3934,1,"TRIPHOP","napakick feat. Taja","DUNE"],\n\'elecfied\':[0,3935,1,"ELECTRO","SySF.","Electrified"],\n\'elecgasm\':[0,3936,1,"ELECTRO","Sota Fujimori","Electrorgasm"],\n\'endless\':[0,3937,1,"JAPANESE REGGAE","DJ Yoshitaka feat.星野奏子","Endless Summer Story"],\n\'eraserdd\':[0,3938,1,"HARDCORE","L.E.D.-G VS GUHROOVY","ERaSeR EnGinE DistorteD"],\n\'eraser\':[0,3939,1,"HARDCORE","L.E.D.-G VS GUHROOVY","ErAseRmoToR maXimUM"],\n\'feelinl5\':[0,3940,1,"HOUSE","youhei shimizu","feeling of love"],\n\'feelinlv\':[0,3941,1,"HOUSE","youhei shimizu","feeling of love"],\n\'firstday\':[0,3943,1,"ELECTRONICA","Timo Maas","First Day"],\n\'flag_pce\':[0,3944,1,"DRUM\'N\'BASS","GUHROOVY fw. NO+CHIN","FLAG OF PEACE"],\n\'fromtime\':[25,3945,1,"TECH HOUSE","sanodg","From Time To Time"],\n\'funktown\':[0,3946,1,"80\'S REVIVAL","Lipps Inc.","Funkytown"],\n\'go_brzk\':[0,3947,1,"HARDCORE","Scott Brown","Go Berzerk"],\n\'gobble\':[23,3948,1,"CANTERBURY&BEAT","Kimitaka Matsumae","GOBBLE"],\n\'guilt_lv\':[0,3949,1,"SHINING RAVE","The Plastic Ambition(jun & DJ YOSHITAKA)","Guilt & Love"],\n\'guilty\':[22,3950,1,"TECHNO","D.J.SETUP","GUILTY"],\n\'guilty5\':[0,3951,1,"TECHNO","D.J.SETUP","GUILTY"],\n\'gymno009\':[0,3952,1,"BOSSA ELECTRO","Studio Bongo Mango feat.Junko Wada(BE THE VOICE)","Gymnopedie 009"],\n\'helsca_t\':[22,3953,1,"GABBAH","Remixed by DJ TECHNORCH fw.GUHROOVY","HELL SCAPER","-Last Escape  ...
